# %% [markdown]
# <a href="https://colab.research.google.com/github/engelsm/mless_fork/blob/main/homework2/Task_2_MLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *#author* Marlon Engels

# %% [markdown]
# Most of this file contains my code, and thus I will not separately mark my contributions but rather explain when code is taken from existing notebooks.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import os

variable_column = ["temp","o3"]
TIMESERIES_DATA_DIR = "/content/drive/MyDrive/mless/"
dataframe = pd.read_csv(os.path.join(TIMESERIES_DATA_DIR, "normalized_data.csv"))
dataframe.head()
# Out:
#    longitude   latitude station_code                   datetime        o3  \
# 0   6.093923  50.754704      DENW094  1997-01-01 00:00:00+00:00 -1.686509
# 1   6.093923  50.754704      DENW094  1997-01-01 01:00:00+00:00 -1.686509
# 2   6.093923  50.754704      DENW094  1997-01-01 02:00:00+00:00 -1.686509
# 3   6.093923  50.754704      DENW094  1997-01-01 03:00:00+00:00 -1.686509
# 4   6.093923  50.754704      DENW094  1997-01-01 04:00:00+00:00 -1.686509
#
#         no2        no      temp       press
# 0 -2.140763 -0.758096 -3.566220 -337.675195
# 1 -2.140763 -0.758096 -3.633418 -337.675195
# 2 -2.140763 -0.758096 -3.646857 -337.675195
# 3 -2.140763 -0.758096 -3.740934 -337.675195
# 4 -2.140763 -0.758096 -3.767813 -337.675195

# %%
dataframe = dataframe.drop(columns=["no2","no","press"])
dataframe.head()
# Out:
#    longitude   latitude station_code                   datetime        o3  \
# 0   6.093923  50.754704      DENW094  1997-01-01 00:00:00+00:00 -1.686509
# 1   6.093923  50.754704      DENW094  1997-01-01 01:00:00+00:00 -1.686509
# 2   6.093923  50.754704      DENW094  1997-01-01 02:00:00+00:00 -1.686509
# 3   6.093923  50.754704      DENW094  1997-01-01 03:00:00+00:00 -1.686509
# 4   6.093923  50.754704      DENW094  1997-01-01 04:00:00+00:00 -1.686509
#
#        temp
# 0 -3.566220
# 1 -3.633418
# 2 -3.646857
# 3 -3.740934
# 4 -3.767813

# %% [markdown]
# # Data Cleaning: Handling Duplicate Station Code and Datetime Combinations
#
# The dataset contains duplicate entries for certain combinations of `station_code` and `datetime`, which can skew analysis and results. To address this issue, we need to clean the dataset by aggregating these duplicate entries. The `clean_duplicate_timestamps` function is designed to handle this by performing the following steps:
#
# 1. **Input Validation and Preparation**:
#    - The function takes a pandas DataFrame (`data`) and a list of column names (`variable_columns`) as inputs.
#    - The DataFrame is expected to have columns for `station_code`, `datetime`, the specified `variable_columns`, `longitude`, and `latitude`.
#    - A copy of the input DataFrame is created to avoid modifying the original data.
#    - The `datetime` column is converted to a pandas datetime format to ensure proper handling of timestamps.
#
# 2. **Aggregation Strategy**:
#    - For the columns listed in `variable_columns` (e.g., `o3` and `temp`), the function computes the **mean** of the values for each unique `station_code` and `datetime` combination.
#    - For the `longitude` and `latitude` columns, the function retains the **first** value encountered for each unique `station_code` and `datetime` pair, as these are typically static for a given station and should not vary.
#
# 3. **Grouping and Aggregation**:
#    - The data is grouped by `station_code` and `datetime`.
#    - The aggregation is performed using the specified strategy: mean for `variable_columns` and first for `longitude` and `latitude`.
#    - The result is a new DataFrame (`data_clean`) with no duplicate `station_code` and `datetime` pairs.
#
# 4. **Output**:
#    - The function returns the cleaned DataFrame, which contains one row per unique `station_code` and `datetime` combination, with aggregated values for the specified columns.

# %%
def clean_duplicate_timestamps(data, variable_columns):
    """
    Aggregate rows with duplicate station_code and datetime, taking the mean of variable_columns
    and the first value of longitude and latitude.

    Args:
        data (pd.DataFrame): Input DataFrame with columns station_code, datetime, variable_columns, lon, lat
        variable_columns (list): List of column names to aggregate with mean

    Returns:
        pd.DataFrame: Cleaned DataFrame with no duplicate station_code/datetime pairs
    """
    data = data.copy()
    data['datetime'] = pd.to_datetime(data['datetime'])

    # Columns to aggregate: mean for variable_columns, first for lon/lat
    agg_cols = {col: 'mean' for col in variable_columns}
    agg_cols.update({'longitude': 'first', 'latitude': 'first'})

    # Group by station_code and datetime, aggregate specified columns
    data_clean = data.groupby(['station_code', 'datetime'], as_index=False).agg(agg_cols)

    return data_clean

data_clean = clean_duplicate_timestamps(dataframe, variable_columns=["o3","temp"])
data_clean.shape
# Out:
# (148435, 6)

# %%
# Function to create continous time-series data with past 24 hours as input and next 6 hours as output
def create_sequences(data, variable_column, n_past=336, n_future=96):
    df = data.copy()
    df['datetime'] = pd.to_datetime(df['datetime'])
    df = df.sort_values(['station_code', 'datetime']).reset_index(drop=True)

    # 1) Encode station_code as a small integer (categorical codes) to save memory
    df['sc_code'] = df['station_code'].astype('category')

    # 2) Boolean mask: True if exactly 1 hour after the previous row (per station)
    is1h = (
        df.groupby('station_code')['datetime']
          .diff()
          .eq(pd.Timedelta(hours=1))
    )

    # 3) Compute how many consecutive “True” over (n_past + n_future - 1) rows
    gap_window = n_past + n_future - 1
    run = (
        is1h.groupby(df['station_code'])
            .rolling(window=gap_window, min_periods=gap_window)
            .sum()
            .reset_index(level=0, drop=True)
    )

    # 4) 'ends' are indices where run == gap_window (end of a full-length continuous block)
    ends = run[run == gap_window].index

    # 5) Grab column‐arrays for encoded station code and the variable
    sc_arr  = df['sc_code'].values
    vals    = df[variable_column].values

    X_list = []
    y_list = []
    for end_idx in ends:
        start_idx = end_idx - gap_window
        if start_idx >= 0 and sc_arr[start_idx] == sc_arr[end_idx]:
            station_block = sc_arr[start_idx : end_idx + 1]
            var_block     = vals[start_idx : end_idx + 1]

            block = np.column_stack((station_block, var_block))

            X_list.append(block[:n_past, :])
            y_list.append(block[n_past:, :])

    if not X_list:
        # No valid windows
        return np.empty((0, n_past, 2)), np.empty((0, n_future, 2))

    X = np.stack(X_list)  # shape = (num_windows, n_past, 2)
    y = np.stack(y_list)  # shape = (num_windows, n_future, 2)
    return X, y

# Function to evaluate model performance
def evaluate_model(y_true, y_pred):
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    print(f"RMSE: {rmse:.4f}")
    return rmse

# %%
context_window = 336
prediction_horizon = 96

X, y = create_sequences(data_clean,variable_column,context_window,prediction_horizon)

train_size = int(len(X) * 0.7)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")
# Out:
# X_train shape: (21493, 336, 3), y_train shape: (21493, 96, 3)
# X_test shape: (9212, 336, 3), y_test shape: (9212, 96, 3)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Extract the first sample: X_train[0] has shape (336, 3)
sample = X_train[0]  # Shape: (336, 3)

# Extract the middle (index 1) and last (index 2) values of the 3rd dimension
feature_1 = sample[:, 1]  # Middle value
feature_2 = sample[:, 2]  # Last value

plt.figure(figsize=(10, 6))
plt.plot(feature_1, label='Feature o3', color='blue')
plt.plot(feature_2, label='Feature temp', color='red')
plt.xlabel('Time Step')
plt.ylabel('Value')
plt.title('Plot of X_train[0]')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Preparing Input Data for MLP Training
#
# To prepare the input data for training a Multi-Layer Perceptron (MLP), the data needs to be formatted appropriately. The following steps transform the input and target datasets (`X_train`, `X_test`, `y_train`, `y_test`) to meet the MLP's expected format:

# %%
# Extract O3 and temperature from X_train and X_test (ignore station ID)
X_train_o3_temp = X_train[:, :, 1:]  # Shape: (21493, 336, 2)
X_test_o3_temp = X_test[:, :, 1:]   # Shape: (9212, 336, 2)

# Reshape X to 2D: (samples, time_steps * features)
X_train_flat = X_train_o3_temp.reshape(X_train_o3_temp.shape[0], -1)  # Shape: (21493, 336*2 = 672)
X_test_flat = X_test_o3_temp.reshape(X_test_o3_temp.shape[0], -1)    # Shape: (9212, 672)

X_train_flat.shape, X_test_flat.shape
# Out:
# ((21493, 672), (9212, 672))

# %%
# Extract O3 from y_train and y_test (target variable)
y_train_o3 = y_train[:, :, 1]  # Shape: (21493, 96)
y_test_o3 = y_test[:, :, 1]    # Shape: (9212, 96)

y_train_o3.shape, y_test_o3.shape
# Out:
# ((21493, 96), (9212, 96))

# %%
#MLP needs numeric types
X_train_flat = np.array(X_train_flat, dtype=np.float32, copy=True)
X_test_flat = np.array(X_test_flat, dtype=np.float32, copy=True)
y_train_o3 = np.array(y_train_o3, dtype=np.float32, copy=True)
y_test_o3 = np.array(y_test_o3, dtype=np.float32, copy=True)

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
import matplotlib.pyplot as plt

# Define hyperparameters
mlp_hidden_units = [512, 256, 128]  # Hidden layer sizes
activation_fn = 'relu'              # Activation function
mlp_optim = 'adam'                  # Optimizer
mlp_loss = 'mse'                    # Loss function
mlp_epochs = 50                     # Number of epochs
mlp_batch_size = 32                 # Batch size

# Build MLP model
mlp_model = Sequential([
    Input(shape=(X_train_flat.shape[1],)),  # Input: 336*2 = 672 features
    Dense(mlp_hidden_units[0], activation=activation_fn)
])

for units in mlp_hidden_units[1:]:
    mlp_model.add(Dense(units, activation=activation_fn))

mlp_model.add(Dense(y_train_o3.shape[1]))  # Output: 96 O3 values

# Compile model
mlp_model.compile(optimizer=mlp_optim, loss=mlp_loss, metrics=['mae'])

# Train model
training = mlp_model.fit(
    X_train_flat, y_train_o3,
    epochs=mlp_epochs,
    batch_size=mlp_batch_size,
    validation_split=0.2,
    verbose=1
)
# Out:
# Epoch 1/50
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.3870 - mae: 0.4742 - val_loss: 0.3493 - val_mae: 0.4670
# Epoch 2/50
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.1932 - mae: 0.3406 - val_loss: 0.3901 - val_mae: 0.4902
# Epoch 3/50
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.1232 - mae: 0.2729 - val_loss: 0.3880 - val_mae: 0.4908
# Epoch 4/50
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0944 - mae: 0.2396 - val_loss: 0.4003 - val_mae: 0.4972
# Epoch 5/50
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0777 - mae: 0.2171 - val_loss: 0.3918 - val_mae: 0.4958
# Epoch 6/50
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0669 - mae: 0.2020 - val_loss: 0.4076 - val_mae: 0.5024
# Epoch 7/50
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0598 - mae: 0.1903 - val_loss: 0.3988 - val_mae: 0.4970
# Epoch 8/50
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0545 - mae: 0.1816 - val_loss: 0.3954 - val_mae: 0.4958
# Epoch 9/50
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0521 - mae: 0.1771 - val_loss: 0.3838 - val_mae: 0.4899
# Epoch 10/50
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0465 - mae: 0.1674 - val_loss: 0.3915 - val_mae: 0.4925
# Epoch 11/50
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0482 - mae: 0.1698 - val_loss: 0.4039 - val_mae: 0.5010
# Epoch 12/50
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0434 - mae: 0.1611 - val_loss: 0.3841 - val_mae: 0.4893
# Epoch 13/50
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0427 - mae: 0.1596 - val_loss: 0.3889 - val_mae: 0.4932
# Epoch 14/50
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0370 - mae: 0.1488 - val_loss: 0.3955 - val_mae: 0.4962
# Epoch 15/50
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0375 - mae: 0.1500 - val_loss: 0.3820 - val_mae: 0.4903
# Epoch 16/50
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0358 - mae: 0.1463 - val_loss: 0.3831 - val_mae: 0.4889
# Epoch 17/50
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0348 - mae: 0.1440 - val_loss: 0.3866 - val_mae: 0.4929
# Epoch 18/50
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0319 - mae: 0.1381 - val_loss: 0.4045 - val_mae: 0.5025
# Epoch 19/50
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0319 - mae: 0.1383 - val_loss: 0.3870 - val_mae: 0.4901
# Epoch 20/50
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0304 - mae: 0.1349 - val_loss: 0.3879 - val_mae: 0.4934
# Epoch 21/50
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0308 - mae: 0.1355 - val_loss: 0.4030 - val_mae: 0.5001
# Epoch 22/50
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0312 - mae: 0.1367 - val_loss: 0.3851 - val_mae: 0.4902
# Epoch 23/50
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0308 - mae: 0.1350 - val_loss: 0.3921 - val_mae: 0.4957
# Epoch 24/50
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0292 - mae: 0.1318 - val_loss: 0.3883 - val_mae: 0.4915
# Epoch 25/50
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0276 - mae: 0.1285 - val_loss: 0.3908 - val_mae: 0.4943
# Epoch 26/50
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0287 - mae: 0.1308 - val_loss: 0.3824 - val_mae: 0.4879
# Epoch 27/50
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0267 - mae: 0.1261 - val_loss: 0.3928 - val_mae: 0.4953
# Epoch 28/50
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0287 - mae: 0.1308 - val_loss: 0.3869 - val_mae: 0.4923
# Epoch 29/50
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0268 - mae: 0.1263 - val_loss: 0.3878 - val_mae: 0.4948
# Epoch 30/50
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0259 - mae: 0.1242 - val_loss: 0.3859 - val_mae: 0.4911
# Epoch 31/50
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0266 - mae: 0.1257 - val_loss: 0.3836 - val_mae: 0.4914
# Epoch 32/50
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0259 - mae: 0.1242 - val_loss: 0.3868 - val_mae: 0.4922
# Epoch 33/50
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0245 - mae: 0.1209 - val_loss: 0.4061 - val_mae: 0.5012
# Epoch 34/50
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0276 - mae: 0.1278 - val_loss: 0.3897 - val_mae: 0.4932
# Epoch 35/50
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0244 - mae: 0.1203 - val_loss: 0.3946 - val_mae: 0.4957
# Epoch 36/50
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0258 - mae: 0.1240 - val_loss: 0.3857 - val_mae: 0.4913
# Epoch 37/50
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0237 - mae: 0.1187 - val_loss: 0.3922 - val_mae: 0.4962
# Epoch 38/50
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0228 - mae: 0.1165 - val_loss: 0.3802 - val_mae: 0.4878
# Epoch 39/50
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0247 - mae: 0.1214 - val_loss: 0.3772 - val_mae: 0.4858
# Epoch 40/50
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0229 - mae: 0.1167 - val_loss: 0.3842 - val_mae: 0.4895
# Epoch 41/50
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0241 - mae: 0.1197 - val_loss: 0.3874 - val_mae: 0.4926
# Epoch 42/50
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0232 - mae: 0.1175 - val_loss: 0.3898 - val_mae: 0.4935
# Epoch 43/50
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0232 - mae: 0.1174 - val_loss: 0.3839 - val_mae: 0.4888
# Epoch 44/50
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0229 - mae: 0.1165 - val_loss: 0.3745 - val_mae: 0.4837
# Epoch 45/50
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0226 - mae: 0.1159 - val_loss: 0.3920 - val_mae: 0.4958
# Epoch 46/50
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0213 - mae: 0.1126 - val_loss: 0.3785 - val_mae: 0.4874
# Epoch 47/50
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0219 - mae: 0.1141 - val_loss: 0.3894 - val_mae: 0.4906
# Epoch 48/50
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0242 - mae: 0.1198 - val_loss: 0.3889 - val_mae: 0.4926
# Epoch 49/50
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0211 - mae: 0.1119 - val_loss: 0.3766 - val_mae: 0.4857
# Epoch 50/50
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0214 - mae: 0.1127 - val_loss: 0.3876 - val_mae: 0.4923

# %%
import numpy as np
import matplotlib.pyplot as plt

# Find the first sample for station DENW094
X_first_idx = np.flatnonzero(X_test[:, 0, 0] == 'DENW094')[0]

# Extract context (O3 only, from X_test[:, :, 1])
X_test_sample = X_test[X_first_idx, :, 1]  # Shape: (336,), normalized O3

# Extract actual future (O3 from y_test_o3)
y_test_sample = y_test_o3[X_first_idx]  # Shape: (96,), normalized O3

# Predict using MLP
X_test_sample_flat = X_test_flat[X_first_idx].reshape(1, -1)  # Shape: (1, 672)
mlp_pred_sample = mlp_model.predict(X_test_sample_flat).flatten()  # Shape: (96,), normalized O3

# Plot (using normalized values)
plt.figure(figsize=(12, 6))
plt.plot(range(336), X_test_sample, label="Context (O3)", color="blue", marker="o")
plt.plot(range(336, 336 + 96), y_test_sample, label="Actual Future (O3)", color="green", marker="o")
plt.plot(range(336, 336 + 96), mlp_pred_sample, label="MLP Prediction (O3)", linestyle="--", color="orange", marker="x")

plt.title("MLP Forecast for Ozone (O3) at Station DENW094 (Normalized)")
plt.xlabel("Time Step (Hours)")
plt.ylabel("O3 (Normalized)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step

# %% [markdown]
# # Ozone Forecasting with an MLP Model
#
# This notebook implements a Multi-Layer Perceptron (MLP) to forecast ozone (O3) levels. The workflow includes:
#
# 1. **Data Preprocessing**:
#    - Load dataset and resolve duplicate `station_code` and `datetime` entries by aggregating means of O3 and temperature.
#
# 2. **Data Preparation**:
#    - Flatten 3D input array (samples, time steps, features) to 2D (samples, time steps * features) for MLP compatibility.
#    - Use past O3 and temperature as input features.
#
# 3. **Model Training and Evaluation**:
#    - Train MLP to predict future O3 values.
#    - Evaluate on test data using RMSE to assess generalization.
#
# 4. **Visualization**:
#    - Plot predictions for the first `DENW094` station sequence, comparing predicted vs. actual O3 values.
#
# ## Outcome
# The preprocessing ensures clean data, and the MLP effectively predicts O3 trends, with the `DENW094` plot demonstrating accurate forecasting.
